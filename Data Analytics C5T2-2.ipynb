# %%
import pandas as pd

# %%
credit = pd.read_csv('default of credit card clients.csv', header =1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c7d590f06270> in <module>
# ----> 1 credit = pd.read_csv('default of credit card clients.csv', header =1)
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
credit = pd.io.parsers.read_csv("default of credit card clients.csv",header=1)

# %%
credit.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
credit.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
# ID                            30000 non-null int64
# LIMIT_BAL                     30000 non-null int64
# SEX                           30000 non-null int64
# EDUCATION                     30000 non-null int64
# MARRIAGE                      30000 non-null int64
# AGE                           30000 non-null int64
# PAY_0                         30000 non-null int64
# PAY_2                         30000 non-null int64
# PAY_3                         30000 non-null int64
# PAY_4                         30000 non-null int64
# PAY_5                         30000 non-null int64
# PAY_6                         30000 non-null int64
# BILL_AMT1                     30000 non-null int64
# BILL_AMT2                     30000 non-null int64
# BILL_AMT3                     30000 non-null int64
# BILL_AMT4                     30000 non-null int64
# ...

# %%
#Checking for null values
print(pd.isnull(credit).sum())
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %%
#no null values found

# %%
#Removing useless variable ID
credit=credit.drop(columns='ID')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-a938c50c0e6c> in <module>
#       1 #Removing useless variable ID
# ----> 2 credit=credit.drop(columns='ID')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
credit.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1     120000    2          2         2   26     -1      2      0      0
# 2      90000    2          2         2   34      0      0      0      0
# 3      50000    2          2         1   37      0      0      0      0
# 4      50000    1          2         1   57     -1      0     -1      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0     -2  ...          0          0          0         0       689         0
# 1      0  ...       3272       3455       3261         0      1000      1000
# 2      0  ...      14331      14948      15549      1518      1500      1000
# 3      0  ...      28314      28959      29547      2000      2019      1200
# 4      0  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
#ID column was removed.

# %%
credit.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1     120000    2          2         2   26     -1      2      0      0
# 2      90000    2          2         2   34      0      0      0      0
# 3      50000    2          2         1   37      0      0      0      0
# 4      50000    1          2         1   57     -1      0     -1      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0     -2  ...          0          0          0         0       689         0
# 1      0  ...       3272       3455       3261         0      1000      1000
# 2      0  ...      14331      14948      15549      1518      1500      1000
# 3      0  ...      28314      28959      29547      2000      2019      1200
# 4      0  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
#Variables no need type change

# %%
credit1=credit

# %%
credit1.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1     120000    2          2         2   26     -1      2      0      0
# 2      90000    2          2         2   34      0      0      0      0
# 3      50000    2          2         1   37      0      0      0      0
# 4      50000    1          2         1   57     -1      0     -1      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0     -2  ...          0          0          0         0       689         0
# 1      0  ...       3272       3455       3261         0      1000      1000
# 2      0  ...      14331      14948      15549      1518      1500      1000
# 3      0  ...      28314      28959      29547      2000      2019      1200
# 4      0  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
#Extracting to csv file

# %%
credit1.to_csv("credit1.csv", index = False, encoding = 'utf8')

# %%
#EXPLORATORY DATA ANALYSIS

# %%
import matplotlib.pyplot as plt

# %%
header = credit1.dtypes.index
print(header)
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
plt.hist(credit1['LIMIT_BAL'])
plt.show()

# %%
plt.hist(credit1['LIMIT_BAL'],bins=5)
plt.show()

# %%
plt.hist(credit1['BILL_AMT1'],bins=5)
plt.show()

# %%
plt.hist(credit1['default payment next month'],bins=5)
plt.show()

# %%
plt.hist(credit1['BILL_AMT2'],bins=5)
plt.show()

# %%
plt.hist(credit1['BILL_AMT3'],bins=5)
plt.show()

# %%
plt.hist(credit1['BILL_AMT4'],bins=5)
plt.show()

# %%
plt.hist(credit1['BILL_AMT5'],bins=5)
plt.show()

# %%
plt.hist(credit1['BILL_AMT6'],bins=5)
plt.show()

# %%
plt.hist(credit1['PAY_AMT1'],bins=5)
plt.show()

# %%
plt.hist(credit1['PAY_AMT2'],bins=5)
plt.show()

# %%
plt.hist(credit1['PAY_AMT3'],bins=5)
plt.show()

# %%
plt.hist(credit1['PAY_AMT4'],bins=5)
plt.show()

# %%
plt.hist(credit1['PAY_AMT5'],bins=5)
plt.show()

# %%
plt.hist(credit1['PAY_AMT6'],bins=5)
plt.show()

# %%
plt.plot(credit1['LIMIT_BAL'])
plt.show()

# %%
x = credit1['PAY_0']
y = credit1['PAY_2']

# %%
plt.scatter(x,y)
plt.show()

# %%
header = credit1.dtypes.index
print(header)
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
A = credit1['BILL_AMT1']
plt.boxplot(A,0,'gD')
plt.show()

# %%
corrMat = credit1.corr()
print(corrMat)
# Out:
#                             LIMIT_BAL       SEX  EDUCATION  MARRIAGE  \
# LIMIT_BAL                    1.000000  0.024755  -0.219161 -0.108139
# SEX                          0.024755  1.000000   0.014232 -0.031389
# EDUCATION                   -0.219161  0.014232   1.000000 -0.143464
# MARRIAGE                    -0.108139 -0.031389  -0.143464  1.000000
# AGE                          0.144713 -0.090874   0.175061 -0.414170
# PAY_0                       -0.271214 -0.057643   0.105364  0.019917
# PAY_2                       -0.296382 -0.070771   0.121566  0.024199
# PAY_3                       -0.286123 -0.066096   0.114025  0.032688
# PAY_4                       -0.267460 -0.060173   0.108793  0.033122
# PAY_5                       -0.249411 -0.055064   0.097520  0.035629
# PAY_6                       -0.235195 -0.044008   0.082316  0.034345
# BILL_AMT1                    0.285430 -0.033642   0.023581 -0.023472
# BILL_AMT2                    0.278314 -0.031183   0.018749 -0.021602
# ...

# %%
covMat = credit1.cov()
print(covMat)
# Out:
#                                LIMIT_BAL          SEX     EDUCATION  \
# LIMIT_BAL                   1.683446e+10  1571.050630 -22474.028945
# SEX                         1.571051e+03     0.239247      0.005502
# EDUCATION                  -2.247403e+04     0.005502      0.624651
# MARRIAGE                   -7.323670e+03    -0.008014     -0.059184
# AGE                         1.730767e+05    -0.409726      1.275380
# PAY_0                      -3.954593e+04    -0.031685      0.093584
# PAY_2                      -4.603765e+04    -0.041442      0.115025
# PAY_3                      -4.443225e+04    -0.038694      0.107861
# PAY_4                      -4.057181e+04    -0.034411      0.100528
# PAY_5                      -3.667056e+04    -0.030521      0.087340
# PAY_6                      -3.509308e+04    -0.024754      0.074816
# BILL_AMT1                   2.727020e+09 -1211.694332   1372.377644
# BILL_AMT2                   2.570130e+09 -1085.595467   1054.657595
# ...

# %%
credit1.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1     120000    2          2         2   26     -1      2      0      0
# 2      90000    2          2         2   34      0      0      0      0
# 3      50000    2          2         1   37      0      0      0      0
# 4      50000    1          2         1   57     -1      0     -1      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0     -2  ...          0          0          0         0       689         0
# 1      0  ...       3272       3455       3261         0      1000      1000
# 2      0  ...      14331      14948      15549      1518      1500      1000
# 3      0  ...      28314      28959      29547      2000      2019      1200
# 4      0  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
header = credit1.dtypes.index
print(header)
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
#Removing entries with no activity as they would not have relevance for the model

# %%
credit1.drop(credit1.index[(credit1.PAY_0==-2) &
            (credit1.PAY_2==-2) & (credit1.PAY_3==-2)&
            (credit1.PAY_4==-2) & (credit1.PAY_5==-2)&
            (credit1.PAY_6==-2)], inplace = True)

# %%
credit1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27891 entries, 0 to 29999
# Data columns (total 24 columns):
# LIMIT_BAL                     27891 non-null int64
# SEX                           27891 non-null int64
# EDUCATION                     27891 non-null int64
# MARRIAGE                      27891 non-null int64
# AGE                           27891 non-null int64
# PAY_0                         27891 non-null int64
# PAY_2                         27891 non-null int64
# PAY_3                         27891 non-null int64
# PAY_4                         27891 non-null int64
# PAY_5                         27891 non-null int64
# PAY_6                         27891 non-null int64
# BILL_AMT1                     27891 non-null int64
# BILL_AMT2                     27891 non-null int64
# BILL_AMT3                     27891 non-null int64
# BILL_AMT4                     27891 non-null int64
# BILL_AMT5                     27891 non-null int64
# ...

# %%
credit1.duplicate().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-75-9481edebb698> in <module>
# ----> 1 credit1.duplicate().sum()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'duplicate'

# %%
credit2=credit1

# %%
credit2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27891 entries, 0 to 29999
# Data columns (total 24 columns):
# LIMIT_BAL                     27891 non-null int64
# SEX                           27891 non-null int64
# EDUCATION                     27891 non-null int64
# MARRIAGE                      27891 non-null int64
# AGE                           27891 non-null int64
# PAY_0                         27891 non-null int64
# PAY_2                         27891 non-null int64
# PAY_3                         27891 non-null int64
# PAY_4                         27891 non-null int64
# PAY_5                         27891 non-null int64
# PAY_6                         27891 non-null int64
# BILL_AMT1                     27891 non-null int64
# BILL_AMT2                     27891 non-null int64
# BILL_AMT3                     27891 non-null int64
# BILL_AMT4                     27891 non-null int64
# BILL_AMT5                     27891 non-null int64
# ...

# %%
credit2.drop('BILL_AMT1',1)
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0          20000    2          2         1   24      2      2     -1     -1
# 1         120000    2          2         2   26     -1      2      0      0
# 2          90000    2          2         2   34      0      0      0      0
# 3          50000    2          2         1   37      0      0      0      0
# 4          50000    1          2         1   57     -1      0     -1      0
# 5          50000    1          1         2   37      0      0      0      0
# 6         500000    1          1         2   29      0      0      0      0
# 7         100000    2          2         2   23      0     -1     -1      0
# 8         140000    2          3         1   28      0      0      2      0
# 9          20000    1          3         2   35     -2     -2     -2     -2
# 10        200000    2          3         2   34      0      0      2      0
# ...

# %%
columns=['BILL_AMT2','BILL_AMT3']
credit2.drop(columns,inplace=True,axis=1)

# %%
credit2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27891 entries, 0 to 29999
# Data columns (total 22 columns):
# LIMIT_BAL                     27891 non-null int64
# SEX                           27891 non-null int64
# EDUCATION                     27891 non-null int64
# MARRIAGE                      27891 non-null int64
# AGE                           27891 non-null int64
# PAY_0                         27891 non-null int64
# PAY_2                         27891 non-null int64
# PAY_3                         27891 non-null int64
# PAY_4                         27891 non-null int64
# PAY_5                         27891 non-null int64
# PAY_6                         27891 non-null int64
# BILL_AMT1                     27891 non-null int64
# BILL_AMT4                     27891 non-null int64
# BILL_AMT5                     27891 non-null int64
# BILL_AMT6                     27891 non-null int64
# PAY_AMT1                      27891 non-null int64
# ...

# %%
columns=['BILL_AMT1','BILL_AMT4','BILL_AMT5','BILL_AMT6','PAY_AMT1','PAY_AMT2','PAY_AMT3','PAY_AMT4','PAY_AMT5','PAY_AMT6']
credit2.drop(columns,inplace=True,axis=1)

# %%
credit2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27891 entries, 0 to 29999
# Data columns (total 12 columns):
# LIMIT_BAL                     27891 non-null int64
# SEX                           27891 non-null int64
# EDUCATION                     27891 non-null int64
# MARRIAGE                      27891 non-null int64
# AGE                           27891 non-null int64
# PAY_0                         27891 non-null int64
# PAY_2                         27891 non-null int64
# PAY_3                         27891 non-null int64
# PAY_4                         27891 non-null int64
# PAY_5                         27891 non-null int64
# PAY_6                         27891 non-null int64
# default payment next month    27891 non-null int64
# dtypes: int64(12)
# memory usage: 2.8 MB

# %%
#Two new dataframes have been created:
#Credit1 contains all the columns from the original files except ID but the instances 
#        with no consumption have been eliminated due to the irrelevance for the main
#        goal of this analysis.
#Credit2 the start point Credit1 and additionally the columns with Bill and Paid amounts
#        have been eliminated as the amounts may be irrelevant as the PAY_ columns are a 
#        good summary based on amount columns
#The Credit1 database is the primary data that will be used for analysis.

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
credit1.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1     120000    2          2         2   26     -1      2      0      0
# 2      90000    2          2         2   34      0      0      0      0
# 3      50000    2          2         1   37      0      0      0      0
# 4      50000    1          2         1   57     -1      0     -1      0
#
#    PAY_5  PAY_6  default payment next month
# 0     -2     -2                           1
# 1      0      2                           1
# 2      0      0                           0
# 3      0      0                           0
# 4      0      0                           0

# %%
credit1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27891 entries, 0 to 29999
# Data columns (total 12 columns):
# LIMIT_BAL                     27891 non-null int64
# SEX                           27891 non-null int64
# EDUCATION                     27891 non-null int64
# MARRIAGE                      27891 non-null int64
# AGE                           27891 non-null int64
# PAY_0                         27891 non-null int64
# PAY_2                         27891 non-null int64
# PAY_3                         27891 non-null int64
# PAY_4                         27891 non-null int64
# PAY_5                         27891 non-null int64
# PAY_6                         27891 non-null int64
# default payment next month    27891 non-null int64
# dtypes: int64(12)
# memory usage: 2.8 MB

# %%
credit2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27891 entries, 0 to 29999
# Data columns (total 12 columns):
# LIMIT_BAL                     27891 non-null int64
# SEX                           27891 non-null int64
# EDUCATION                     27891 non-null int64
# MARRIAGE                      27891 non-null int64
# AGE                           27891 non-null int64
# PAY_0                         27891 non-null int64
# PAY_2                         27891 non-null int64
# PAY_3                         27891 non-null int64
# PAY_4                         27891 non-null int64
# PAY_5                         27891 non-null int64
# PAY_6                         27891 non-null int64
# default payment next month    27891 non-null int64
# dtypes: int64(12)
# memory usage: 2.8 MB

# %%
credit = pd.read_csv('default of credit card clients.csv', header =1)

# %%
credit.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
credit.drop('ID',1)
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0          20000    2          2         1   24      2      2     -1     -1
# 1         120000    2          2         2   26     -1      2      0      0
# 2          90000    2          2         2   34      0      0      0      0
# 3          50000    2          2         1   37      0      0      0      0
# 4          50000    1          2         1   57     -1      0     -1      0
# 5          50000    1          1         2   37      0      0      0      0
# 6         500000    1          1         2   29      0      0      0      0
# 7         100000    2          2         2   23      0     -1     -1      0
# 8         140000    2          3         1   28      0      0      2      0
# 9          20000    1          3         2   35     -2     -2     -2     -2
# 10        200000    2          3         2   34      0      0      2      0
# ...

# %%
credit.drop(credit.index[(credit.PAY_0==-2) &
            (credit.PAY_2==-2) & (credit.PAY_3==-2)&
            (credit.PAY_4==-2) & (credit.PAY_5==-2)&
            (credit.PAY_6==-2)], inplace = True)

# %%
credit.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
credit.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  27891.000000    27891.000000  27891.000000  27891.000000  27891.000000
# mean   14838.943387   161114.685024      1.597720      1.866265      1.556273
# std     8638.976101   127851.517469      0.490367      0.784649      0.522167
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7360.500000    50000.000000      1.000000      1.000000      1.000000
# 50%    14727.000000   130000.000000      2.000000      2.000000      2.000000
# 75%    22237.500000   230000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  27891.000000  27891.000000  27891.000000  27891.000000  27891.000000
# mean      35.357606      0.133269      0.007350     -0.027536     -0.086121
# ...

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27891 entries, 0 to 29999
# Data columns (total 25 columns):
# ID                            27891 non-null int64
# LIMIT_BAL                     27891 non-null int64
# SEX                           27891 non-null int64
# EDUCATION                     27891 non-null int64
# MARRIAGE                      27891 non-null int64
# AGE                           27891 non-null int64
# PAY_0                         27891 non-null int64
# PAY_2                         27891 non-null int64
# PAY_3                         27891 non-null int64
# PAY_4                         27891 non-null int64
# PAY_5                         27891 non-null int64
# PAY_6                         27891 non-null int64
# BILL_AMT1                     27891 non-null int64
# BILL_AMT2                     27891 non-null int64
# BILL_AMT3                     27891 non-null int64
# BILL_AMT4                     27891 non-null int64
# ...

# %%
credit.drop('ID',1)
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0          20000    2          2         1   24      2      2     -1     -1
# 1         120000    2          2         2   26     -1      2      0      0
# 2          90000    2          2         2   34      0      0      0      0
# 3          50000    2          2         1   37      0      0      0      0
# 4          50000    1          2         1   57     -1      0     -1      0
# 5          50000    1          1         2   37      0      0      0      0
# 6         500000    1          1         2   29      0      0      0      0
# 7         100000    2          2         2   23      0     -1     -1      0
# 8         140000    2          3         1   28      0      0      2      0
# 9          20000    1          3         2   35     -2     -2     -2     -2
# 10        200000    2          3         2   34      0      0      2      0
# ...

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27891 entries, 0 to 29999
# Data columns (total 25 columns):
# ID                            27891 non-null int64
# LIMIT_BAL                     27891 non-null int64
# SEX                           27891 non-null int64
# EDUCATION                     27891 non-null int64
# MARRIAGE                      27891 non-null int64
# AGE                           27891 non-null int64
# PAY_0                         27891 non-null int64
# PAY_2                         27891 non-null int64
# PAY_3                         27891 non-null int64
# PAY_4                         27891 non-null int64
# PAY_5                         27891 non-null int64
# PAY_6                         27891 non-null int64
# BILL_AMT1                     27891 non-null int64
# BILL_AMT2                     27891 non-null int64
# BILL_AMT3                     27891 non-null int64
# BILL_AMT4                     27891 non-null int64
# ...

# %%
ID=['ID']
credit.drop(ID,inplace=True,axis=1)

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27891 entries, 0 to 29999
# Data columns (total 24 columns):
# LIMIT_BAL                     27891 non-null int64
# SEX                           27891 non-null int64
# EDUCATION                     27891 non-null int64
# MARRIAGE                      27891 non-null int64
# AGE                           27891 non-null int64
# PAY_0                         27891 non-null int64
# PAY_2                         27891 non-null int64
# PAY_3                         27891 non-null int64
# PAY_4                         27891 non-null int64
# PAY_5                         27891 non-null int64
# PAY_6                         27891 non-null int64
# BILL_AMT1                     27891 non-null int64
# BILL_AMT2                     27891 non-null int64
# BILL_AMT3                     27891 non-null int64
# BILL_AMT4                     27891 non-null int64
# BILL_AMT5                     27891 non-null int64
# ...

# %%
credit.groupby('LIMIT_BAL')['LIMIT_BAL'].count()
# Out:
# LIMIT_BAL
# 10000       489
# 16000         2
# 20000      1951
# 30000      1571
# 40000       223
# 50000      3313
# 60000       817
# 70000       728
# 80000      1501
# 90000       627
# 100000     1012
# 110000      577
# 120000      692
# 130000      711
# 140000      721
# 150000      998
# 160000      630
# 170000      497
# 180000      903
# 190000      221
# 200000     1328
# 210000      659
# 220000      430
# 230000      634
# 240000      558
# 250000      312
# 260000      465
# 270000      208
# 280000      421
# 290000      309
#            ...
# 500000      617
# 510000       18
# 520000       18
# 530000        9
# 540000        6
# 550000       18
# 560000        8
# 570000        7
# 580000       11
# 590000        5
# 600000       11
# 610000       10
# 620000        8
# 630000        6
# 640000        6
# 650000        2
# 660000        3
# 670000        3
# 680000        4
# 690000        1
# 700000        5
# 710000        6
# 720000        3
# ...

# %%
credit.groupby('SEX')['SEX'].count()
# Out:
# SEX
# 1    11220
# 2    16671
# Name: SEX, dtype: int64

# %%
#1=male, 2=female

# %%
credit.groupby('EDUCATION')['EDUCATION'].count()
# Out:
# EDUCATION
# 0       11
# 1     9518
# 2    13306
# 3     4651
# 4      102
# 5      257
# 6       46
# Name: EDUCATION, dtype: int64

# %%
#1 = graduate school; 2 = university; 3 = high school; 0, 4, 5, 6 = others

# %%
credit.groupby('MARRIAGE')['MARRIAGE'].count()
# Out:
# MARRIAGE
# 0       48
# 1    12592
# 2    14939
# 3      312
# Name: MARRIAGE, dtype: int64

# %%
#1 = married; 2 = single; 3 = divorce; 0=others

# %%
credit.groupby('AGE')['AGE'].count()
# Out:
# AGE
# 21      66
# 22     552
# 23     907
# 24    1101
# 25    1145
# 26    1205
# 27    1397
# 28    1320
# 29    1499
# 30    1291
# 31    1110
# 32    1054
# 33    1056
# 34    1061
# 35    1034
# 36    1005
# 37     945
# 38     858
# 39     875
# 40     795
# 41     755
# 42     739
# 43     612
# 44     639
# 45     568
# 46     522
# 47     457
# 48     431
# 49     417
# 50     379
# 51     315
# 52     286
# 53     294
# 54     223
# 55     201
# 56     168
# 57     114
# 58     105
# 59      77
# 60      63
# 61      53
# 62      41
# 63      27
# 64      29
# 65      22
# 66      23
# 67      15
# 68       5
# 69      13
# 70      10
# 71       3
# 72       2
# 73       2
# 74       1
# 75       3
# 79       1
# Name: AGE, dtype: int64

# %%
credit.groupby('default payment next month')['default payment next month'].count()
# Out:
# default payment next month
# 0    21539
# 1     6352
# Name: default payment next month, dtype: int64

# %%
# Histogram Education Levels using Seaborn
Chart1 = sns.catplot('EDUCATION', data=credit, kind='count', aspect=1.0)
Chart1.set_xlabels('Education')

# %%
# Histogram Gender using Seaborn
Chart2 = sns.catplot('SEX', data=credit, kind='count', aspect=1.0)
Chart2.set_xlabels('Gender')
Chart2.set_xticklabels(['Male', 'Female'])

# %%
# Histogram Gender using Seaborn
Chart3 = sns.catplot('MARRIAGE', data=credit, kind='count', aspect=1.0)
Chart3.set_xlabels('Marital Status')
Chart3.set_xticklabels(['Others','Married', 'Single','Divorce'])

# %%
# Histogram Default using Seaborn
Chart4 = sns.catplot('default payment next month', data=credit, kind='count', aspect=1.0)
Chart4.set_xlabels('Payment Default')
Chart4.set_xticklabels(['No Default','Default'])

# %%
# Histogram Age using Seaborn
Chart5 = sns.catplot('AGE', data=credit, kind='count', aspect=1.0)
Chart5.set_xlabels('Age')

# %%
#Another way to look at ages would be
credit['AGE'].hist(bins=20)

# %%
#It would be helpful to see different attributes plot together to help us determine
#possible relationships
# Firt to all create bins for Limit credit amount
# 1: <100k
# 2: 100k-190k
# 3: 200k-290k
# 4: 300-390k
# 5: 400k+
arr = np.array([0,99999,199999,299999,399999,1100000])

# %%
credit['Limit_Bins'] = arr.searchsorted(credit.LIMIT_BAL)

# %%
credit.groupby('Limit_Bins')['Limit_Bins'].count()
# Out:
# Limit_Bins
# 1    11222
# 2     6962
# 3     5324
# 4     2595
# 5     1788
# Name: Limit_Bins, dtype: int64

# %%
# Split Age into 4 age groups
# 1: <30
# 2: 30-39
# 3: 40-49
# 4: 50+
arr_age = np.array([0,29,39,49,80])

# %%
credit['Age_Bins'] = arr_age.searchsorted(credit.AGE)

# %%
credit.groupby('Age_Bins')['Age_Bins'].count()
# Out:
# Age_Bins
# 1     9192
# 2    10289
# 3     5935
# 4     2475
# Name: Age_Bins, dtype: int64

# %%
#Reduce Education into 4 groups
credit['EDUCATION'].replace([4,5,6],0, inplace=True)

# %%
credit.groupby('EDUCATION')['EDUCATION'].count()
# Out:
# EDUCATION
# 0      416
# 1     9518
# 2    13306
# 3     4651
# Name: EDUCATION, dtype: int64

# %%
Chart6 = sns.catplot('Limit_Bins', data=credit, hue='default payment next month', kind='count', 
                  aspect=1, legend=False)
Chart6.set_xticklabels(['<100k', '100k-190k','200k-290k', 
                    '300k-390k', '400k+'])
plt.legend(title='Credit Limit vs. Default', loc='upper right', 
           labels=['No Default', 'Default'])
plt.show(fg_ls)

# %%
#Based on the above plot, it is possible to conclude that the majority of the default cases 
#happened within users with given credit under $200k

# %%
Chart7 = sns.catplot('Age_Bins', data=credit, hue='default payment next month', kind='count', 
                  aspect=1, legend=False)
Chart7.set_xticklabels(['<30','30-39','40-49','50+k'])
plt.legend(title='Age vs. Default', loc='upper right', 
           labels=['No Default', 'Default'])
plt.show(fg_ls)

# %%
#The above chart shows that the lower percentage of default is in the 30 to 40 age group

# %%
Chart8 = sns.catplot('EDUCATION', data=credit, hue='default payment next month', kind='count', 
                  aspect=1, legend=False)
Chart8.set_xticklabels(['Other','GS','U','HS'])
plt.legend(title='Education vs. Default', loc='upper right', 
           labels=['No Default', 'Default'])
plt.show(fg_ls)

# %%
Chart9 = sns.catplot('MARRIAGE', data=credit, hue='default payment next month', kind='count', 
                  aspect=1, legend=False)
Chart9.set_xticklabels(['Others','Married', 'Single','Divorce'])
plt.legend(title='Marital Status vs. Default', loc='upper right', 
           labels=['No Default', 'Default'])
plt.show(fg_ls)

# %%
#The Chart 8 suggest show a higher percentage of default within married clients.

# %%
Chart10 = sns.catplot('SEX', data=credit, hue='default payment next month', kind='count', 
                  aspect=1, legend=False)
Chart10.set_xticklabels(['male','female'])
plt.legend(title='Gender vs. Default', loc='upper right', 
           labels=['No Default', 'Default'])
plt.show(fg_ls)

# %%
#While there is a higher percentage of females in the group, Chart 10 shows a higher percentage of default within 
#male clients

# %%
corrMat3 = credit.corr()
corrMat3.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_2a1e561e_ca10_11e9_9f59_f40f241919c8row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_2a1e561e_ca10_11e9_9f59_f40f241919c8row0_col1 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_2a1e561e_ca10_11e9_9f59_f40f241919c8row0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_2a1e561e_ca10_11e9_9f59_f40f241919c8row0_col3 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_2a1e561e_ca10_11e9_9f59_f40f241919c8row0_col4 {
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }    #T_2a1e561e_ca10_11e9_9f59_f40f241919c8row0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_2a1e561e_ca10_11e9_9f59_f40f241919c8row0_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
# ...

# %%
#Based on previous correlation matrix further attributes reduction will be performed removing the 
#amount of previous payment attributes.

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27891 entries, 0 to 29999
# Data columns (total 26 columns):
# LIMIT_BAL                     27891 non-null int64
# SEX                           27891 non-null int64
# EDUCATION                     27891 non-null int64
# MARRIAGE                      27891 non-null int64
# AGE                           27891 non-null int64
# PAY_0                         27891 non-null int64
# PAY_2                         27891 non-null int64
# PAY_3                         27891 non-null int64
# PAY_4                         27891 non-null int64
# PAY_5                         27891 non-null int64
# PAY_6                         27891 non-null int64
# BILL_AMT1                     27891 non-null int64
# BILL_AMT2                     27891 non-null int64
# BILL_AMT3                     27891 non-null int64
# BILL_AMT4                     27891 non-null int64
# BILL_AMT5                     27891 non-null int64
# ...

# %%
#Extracting Credit to csv.file
credit.to_csv("credit.csv", index = False, encoding = 'utf8')

# %%
PAY_AMT1=['PAY_AMT1']
PAY_AMT2=['PAY_AMT2']
credit.drop(PAY_AMT1,PAY_AMT2,inplace=True,axis=2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-178-6c967ad0d061> in <module>
#       1 PAY_AMT1=['PAY_AMT1']
#       2 PAY_AMT2=['PAY_AMT2']
# ----> 3 credit.drop(PAY_AMT1,PAY_AMT2,inplace=True,axis=2)
#
# TypeError: drop() got multiple values for argument 'axis'

# %%
credit1=credit.drop(['PAY_AMT1','PAY_AMT2','PAY_AMT3','PAY_AMT4','PAY_AMT5','PAY_AMT6','Limit_Bins','Age_Bins'],axis=1)

# %%
credit1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27891 entries, 0 to 29999
# Data columns (total 18 columns):
# LIMIT_BAL                     27891 non-null int64
# SEX                           27891 non-null int64
# EDUCATION                     27891 non-null int64
# MARRIAGE                      27891 non-null int64
# AGE                           27891 non-null int64
# PAY_0                         27891 non-null int64
# PAY_2                         27891 non-null int64
# PAY_3                         27891 non-null int64
# PAY_4                         27891 non-null int64
# PAY_5                         27891 non-null int64
# PAY_6                         27891 non-null int64
# BILL_AMT1                     27891 non-null int64
# BILL_AMT2                     27891 non-null int64
# BILL_AMT3                     27891 non-null int64
# BILL_AMT4                     27891 non-null int64
# BILL_AMT5                     27891 non-null int64
# ...

# %%
#Extracting Credit1 to csv.file
credit1.to_csv("credit1.csv", index = False, encoding = 'utf8')
